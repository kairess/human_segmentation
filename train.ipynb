# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Model
from keras.layers import Input, concatenate, Dropout, Reshape, Permute, Activation, ZeroPadding2D, Cropping2D
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
IMG_HEIGHT = 256
IMG_WIDTH = 256
BATCH_SIZE = 16

x_train = np.load('data/x_train.npz')['data'].astype(np.float32)
y_train = np.load('data/y_train.npz')['data'].astype(np.float32)
x_val = np.load('data/x_val.npz')['data'].astype(np.float32)
y_val = np.load('data/y_val.npz')['data'].astype(np.float32)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (12706, 256, 256, 3) (12706, 256, 256, 2)
# (5000, 256, 256, 3) (5000, 256, 256, 2)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    brightness_range=[0.8, 1.2]
)

val_datagen = ImageDataGenerator(
    rescale=1./255
)

train_gen = train_datagen.flow(
    x_train,
    y_train,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_gen = val_datagen.flow(
    x_val,
    y_val,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %%
inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# encode
# 256x256
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(inputs)
conv1 = Dropout(0.2)(conv1)
conv1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

# 128x128
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(pool1)
conv2 = Dropout(0.2)(conv2)
conv2 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

# 64x64
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(pool2)
conv3 = Dropout(0.2)(conv3)
conv3 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

# decode
up8 = UpSampling2D(size=(2, 2))(pool3)
up8 = concatenate([up8, conv3], axis=-1)
conv8 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(up8)
conv8 = Dropout(0.2)(conv8)
conv8 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(conv8)

up9 = UpSampling2D(size=(2, 2))(conv8)
up9 = concatenate([up9, conv2], axis=-1)
conv9 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(up9)
conv9 = Dropout(0.2)(conv9)
conv9 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(conv9)

up10 = UpSampling2D(size=(2, 2))(conv9)
up10 = concatenate([up10, conv1], axis=-1)
conv10 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(up10)
conv10 = Dropout(0.2)(conv10)
conv10 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='orthogonal')(conv10)

conv11 = Conv2D(2, (1, 1), padding='same', activation='relu',
                kernel_initializer='he_normal', kernel_regularizer=l2(0.005))(conv10)
conv11 = Reshape((IMG_HEIGHT * IMG_WIDTH, 2))(conv11)
# conv11 = Reshape((2, IMG_HEIGHT * IMG_WIDTH))(conv11)
# conv11 = Permute((2, 1))(conv11)

conv11 = Activation('softmax')(conv11)

outputs = Reshape((IMG_HEIGHT, IMG_WIDTH, 2))(conv11)

model = Model(inputs=inputs, outputs=outputs)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 128, 64) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  147584      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 128)  589952      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64, 64, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 128)  147584      dropout_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           up_sampling2d_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 64) 147520      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 128, 128, 64) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 64) 36928       dropout_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           up_sampling2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 256, 32) 36896       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256, 256, 32) 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 32) 9248        dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 2)  66          conv2d_12[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 65536, 2)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 65536, 2)     0           reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 256, 256, 2)  0           activation_1[0][0]
# ==================================================================================================
# Total params: 1,541,122
# Trainable params: 1,541,122
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(train_gen,
    validation_data=val_gen,
    epochs=20,
    callbacks=[
        ModelCheckpoint('models/unet.h5', monitor='val_acc', save_best_only=True, verbose=1)
    ]
)
# Out:
# Epoch 1/20
# 795/795 [==============================] - 222s 279ms/step - loss: 0.2172 - acc: 0.8989 - val_loss: 0.1399 - val_acc: 0.9426
#
# Epoch 00001: val_acc improved from -inf to 0.94261, saving model to models/unet.h5
# Epoch 2/20
# 795/795 [==============================] - 221s 277ms/step - loss: 0.1367 - acc: 0.9438 - val_loss: 0.1055 - val_acc: 0.9592
#
# Epoch 00002: val_acc improved from 0.94261 to 0.95920, saving model to models/unet.h5
# Epoch 3/20
# 795/795 [==============================] - 223s 280ms/step - loss: 0.1033 - acc: 0.9595 - val_loss: 0.0825 - val_acc: 0.9684
#
# Epoch 00003: val_acc improved from 0.95920 to 0.96843, saving model to models/unet.h5
# Epoch 4/20
# 795/795 [==============================] - 224s 281ms/step - loss: 0.0879 - acc: 0.9661 - val_loss: 0.0732 - val_acc: 0.9727
#
# Epoch 00004: val_acc improved from 0.96843 to 0.97265, saving model to models/unet.h5
# Epoch 5/20
# 795/795 [==============================] - 222s 279ms/step - loss: 0.0788 - acc: 0.9699 - val_loss: 0.0756 - val_acc: 0.9719
#
# Epoch 00005: val_acc did not improve from 0.97265
# Epoch 6/20
# 795/795 [==============================] - 225s 283ms/step - loss: 0.0749 - acc: 0.9716 - val_loss: 0.0649 - val_acc: 0.9760
#
# Epoch 00006: val_acc improved from 0.97265 to 0.97604, saving model to models/unet.h5
# Epoch 7/20
# 795/795 [==============================] - 224s 282ms/step - loss: 0.0703 - acc: 0.9734 - val_loss: 0.0620 - val_acc: 0.9769
#
# Epoch 00007: val_acc improved from 0.97604 to 0.97689, saving model to models/unet.h5
# Epoch 8/20
# 795/795 [==============================] - 228s 287ms/step - loss: 0.0666 - acc: 0.9749 - val_loss: 0.0582 - val_acc: 0.9782
#
# Epoch 00008: val_acc improved from 0.97689 to 0.97818, saving model to models/unet.h5
# Epoch 9/20
# 795/795 [==============================] - 232s 292ms/step - loss: 0.0647 - acc: 0.9756 - val_loss: 0.0577 - val_acc: 0.9786
#
# Epoch 00009: val_acc improved from 0.97818 to 0.97863, saving model to models/unet.h5
# Epoch 10/20
# 795/795 [==============================] - 233s 294ms/step - loss: 0.0617 - acc: 0.9769 - val_loss: 0.0619 - val_acc: 0.9783
#
# Epoch 00010: val_acc did not improve from 0.97863
# Epoch 11/20
# 795/795 [==============================] - 234s 295ms/step - loss: 0.0606 - acc: 0.9774 - val_loss: 0.0575 - val_acc: 0.9787
#
# Epoch 00011: val_acc improved from 0.97863 to 0.97873, saving model to models/unet.h5
# Epoch 12/20
# 795/795 [==============================] - 236s 296ms/step - loss: 0.0590 - acc: 0.9781 - val_loss: 0.0579 - val_acc: 0.9786
#
# Epoch 00012: val_acc did not improve from 0.97873
# Epoch 13/20
# 795/795 [==============================] - 236s 297ms/step - loss: 0.0577 - acc: 0.9785 - val_loss: 0.0547 - val_acc: 0.9799
#
# Epoch 00013: val_acc improved from 0.97873 to 0.97989, saving model to models/unet.h5
# Epoch 14/20
# 795/795 [==============================] - 236s 297ms/step - loss: 0.0567 - acc: 0.9790 - val_loss: 0.0568 - val_acc: 0.9793
#
# Epoch 00014: val_acc did not improve from 0.97989
# Epoch 15/20
# 795/795 [==============================] - 236s 297ms/step - loss: 0.0546 - acc: 0.9798 - val_loss: 0.0540 - val_acc: 0.9803
#
# Epoch 00015: val_acc improved from 0.97989 to 0.98030, saving model to models/unet.h5
# Epoch 16/20
# 795/795 [==============================] - 236s 297ms/step - loss: 0.0545 - acc: 0.9799 - val_loss: 0.0583 - val_acc: 0.9790
#
# Epoch 00016: val_acc did not improve from 0.98030
# Epoch 17/20
# 795/795 [==============================] - 235s 295ms/step - loss: 0.0526 - acc: 0.9806 - val_loss: 0.0529 - val_acc: 0.9808
#
# Epoch 00017: val_acc improved from 0.98030 to 0.98078, saving model to models/unet.h5
# Epoch 18/20
# 795/795 [==============================] - 236s 297ms/step - loss: 0.0521 - acc: 0.9807 - val_loss: 0.0544 - val_acc: 0.9802
#
# Epoch 00018: val_acc did not improve from 0.98078
# Epoch 19/20
# 795/795 [==============================] - 236s 296ms/step - loss: 0.0514 - acc: 0.9811 - val_loss: 0.0538 - val_acc: 0.9808
#
# Epoch 00019: val_acc improved from 0.98078 to 0.98083, saving model to models/unet.h5
# Epoch 20/20
# 795/795 [==============================] - 236s 297ms/step - loss: 0.0501 - acc: 0.9816 - val_loss: 0.0523 - val_acc: 0.9806
#
# Epoch 00020: val_acc did not improve from 0.98083
