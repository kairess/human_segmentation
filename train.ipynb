# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.models import Model
from keras.layers import Input, concatenate, Dropout, Reshape, Permute, Activation, ZeroPadding2D, Cropping2D, Add
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, DepthwiseConv2D
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
IMG_HEIGHT = 256
IMG_WIDTH = 256
BATCH_SIZE = 16

x_train = np.load('data/x_train.npz')['data'].astype(np.float32)
y_train = np.load('data/y_train.npz')['data'].astype(np.float32)
x_val = np.load('data/x_val.npz')['data'].astype(np.float32)
y_val = np.load('data/y_val.npz')['data'].astype(np.float32)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (12706, 256, 256, 3) (12706, 256, 256, 2)
# (5000, 256, 256, 3) (5000, 256, 256, 2)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    brightness_range=[0.7, 1.3]
)

val_datagen = ImageDataGenerator(
    rescale=1./255
)

train_gen = train_datagen.flow(
    x_train,
    y_train,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_gen = val_datagen.flow(
    x_val,
    y_val,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %%
inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# encode
conv1 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(inputs)
# conv1 = Dropout(0.2)(conv1)
conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv1)
pool1 = MaxPooling2D(pool_size=2)(conv1)
# (128, 128, 64)

shortcut_1 = pool1

conv2 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(pool1)
# conv2 = Dropout(0.2)(conv2)
conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv2)
pool2 = MaxPooling2D(pool_size=2)(conv2)
# (64, 64, 128)

shortcut_2 = pool2

conv3 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(pool2)
# conv3 = Dropout(0.2)(conv3)
conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv3)
pool3 = MaxPooling2D(pool_size=2)(conv3)
# (32, 32, 256)

# middle depthwiseconv nodes
shortcut_3 = pool3

mid = DepthwiseConv2D(3, activation='relu', padding='same', kernel_initializer='orthogonal')(pool3)
mid = Conv2D(256, 1, activation='relu', padding='same', kernel_initializer='orthogonal')(mid)

mid = DepthwiseConv2D(3, activation='relu', padding='same', kernel_initializer='orthogonal')(mid)
mid = Conv2D(256, 1, activation='relu', padding='same', kernel_initializer='orthogonal')(mid)

mid = Add()([shortcut_3, mid])

# decode
up8 = UpSampling2D(size=2)(mid)
up8 = concatenate([up8, conv3], axis=-1)
conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(up8)
# conv8 = Dropout(0.2)(conv8)
conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv8)
# (64, 64, 128)

conv8 = Add()([shortcut_2, conv8])

up9 = UpSampling2D(size=2)(conv8)
up9 = concatenate([up9, conv2], axis=-1)
conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(up9)
# conv9 = Dropout(0.2)(conv9)
conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv9)
# (128, 128, 64)

conv9 = Add()([shortcut_1, conv9])

up10 = UpSampling2D(size=2)(conv9)
up10 = concatenate([up10, conv1], axis=-1)
conv10 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(up10)
# conv10 = Dropout(0.2)(conv10)
conv10 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='orthogonal')(conv10)
# (256, 256, 32)

conv11 = Conv2D(2, 1, padding='same', activation='relu',
                kernel_initializer='he_normal', kernel_regularizer=l2(0.005))(conv10)
conv11 = Reshape((IMG_HEIGHT * IMG_WIDTH, 2))(conv11)
# (256, 256, 2)

conv11 = Activation('softmax')(conv11)

outputs = Reshape((IMG_HEIGHT, IMG_WIDTH, 2))(conv11)

model = Model(inputs=inputs, outputs=outputs)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 256, 32) 896         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 256, 256, 64) 18496       conv2d_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 128, 128, 64) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 64) 36928       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 128 73856       conv2d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 64, 64, 128)  0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 128)  147584      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 64, 256)  295168      conv2d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 32, 32, 256)  0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 32, 32, 256)  2560        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 256)  65792       depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 32, 32, 256)  2560        conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 256)  65792       depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 256)  0           max_pooling2d_12[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 512)  0           up_sampling2d_7[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 64, 64, 128)  589952      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 128)  0           max_pooling2d_11[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 128 0           add_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 128, 256 0           up_sampling2d_8[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 128, 128, 64) 147520      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 128, 128, 64) 0           max_pooling2d_10[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 256, 256, 64) 0           add_9[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 256, 256, 128 0           up_sampling2d_9[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 256, 256, 32) 36896       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 256, 256, 2)  66          conv2d_51[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 65536, 2)     0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 65536, 2)     0           reshape_5[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 256, 256, 2)  0           activation_3[0][0]
# ==================================================================================================
# Total params: 1,677,826
# Trainable params: 1,677,826
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(train_gen,
    validation_data=val_gen,
    epochs=100,
    callbacks=[
        ModelCheckpoint('models/unet_no_drop.h5', monitor='val_acc', save_best_only=True, verbose=1),
        ReduceLROnPlateau(monitor='val_acc', factor=0.2, patience=10, verbose=1, min_lr=1e-05)

    ]
)
# Out:
# Epoch 1/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.1887 - acc: 0.9232 - val_loss: 0.1309 - val_acc: 0.9515
#
# Epoch 00001: val_acc improved from -inf to 0.95152, saving model to models/unet_no_drop.h5
# Epoch 2/100
# 795/795 [==============================] - 190s 240ms/step - loss: 0.1109 - acc: 0.9572 - val_loss: 0.0933 - val_acc: 0.9653
#
# Epoch 00002: val_acc improved from 0.95152 to 0.96530, saving model to models/unet_no_drop.h5
# Epoch 3/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0833 - acc: 0.9688 - val_loss: 0.0690 - val_acc: 0.9749
#
# Epoch 00003: val_acc improved from 0.96530 to 0.97489, saving model to models/unet_no_drop.h5
# Epoch 4/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0679 - acc: 0.9749 - val_loss: 0.0603 - val_acc: 0.9779
#
# Epoch 00004: val_acc improved from 0.97489 to 0.97787, saving model to models/unet_no_drop.h5
# Epoch 5/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0604 - acc: 0.9778 - val_loss: 0.0624 - val_acc: 0.9776
#
# Epoch 00005: val_acc did not improve from 0.97787
# Epoch 6/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0557 - acc: 0.9797 - val_loss: 0.0579 - val_acc: 0.9795
#
# Epoch 00006: val_acc improved from 0.97787 to 0.97951, saving model to models/unet_no_drop.h5
# Epoch 7/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0509 - acc: 0.9815 - val_loss: 0.0547 - val_acc: 0.9816
#
# Epoch 00007: val_acc improved from 0.97951 to 0.98158, saving model to models/unet_no_drop.h5
# Epoch 8/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0483 - acc: 0.9825 - val_loss: 0.0498 - val_acc: 0.9820
#
# Epoch 00008: val_acc improved from 0.98158 to 0.98197, saving model to models/unet_no_drop.h5
# Epoch 9/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0452 - acc: 0.9837 - val_loss: 0.0596 - val_acc: 0.9809
#
# Epoch 00009: val_acc did not improve from 0.98197
# Epoch 10/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0432 - acc: 0.9844 - val_loss: 0.0491 - val_acc: 0.9828
#
# Epoch 00010: val_acc improved from 0.98197 to 0.98282, saving model to models/unet_no_drop.h5
# Epoch 11/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0414 - acc: 0.9851 - val_loss: 0.0504 - val_acc: 0.9824
#
# Epoch 00011: val_acc did not improve from 0.98282
# Epoch 12/100
# 795/795 [==============================] - 188s 237ms/step - loss: 0.0398 - acc: 0.9858 - val_loss: 0.0440 - val_acc: 0.9844
#
# Epoch 00012: val_acc improved from 0.98282 to 0.98436, saving model to models/unet_no_drop.h5
# Epoch 13/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0389 - acc: 0.9861 - val_loss: 0.0442 - val_acc: 0.9845
#
# Epoch 00013: val_acc improved from 0.98436 to 0.98447, saving model to models/unet_no_drop.h5
# Epoch 14/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0366 - acc: 0.9870 - val_loss: 0.0522 - val_acc: 0.9833
#
# Epoch 00014: val_acc did not improve from 0.98447
# Epoch 15/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0359 - acc: 0.9872 - val_loss: 0.0480 - val_acc: 0.9841
#
# Epoch 00015: val_acc did not improve from 0.98447
# Epoch 16/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0338 - acc: 0.9880 - val_loss: 0.0487 - val_acc: 0.9843
#
# Epoch 00016: val_acc did not improve from 0.98447
# Epoch 17/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0335 - acc: 0.9881 - val_loss: 0.0589 - val_acc: 0.9810
#
# Epoch 00017: val_acc did not improve from 0.98447
# Epoch 18/100
# 795/795 [==============================] - 193s 242ms/step - loss: 0.0323 - acc: 0.9886 - val_loss: 0.0479 - val_acc: 0.9845
#
# Epoch 00018: val_acc improved from 0.98447 to 0.98449, saving model to models/unet_no_drop.h5
# Epoch 19/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0311 - acc: 0.9890 - val_loss: 0.0461 - val_acc: 0.9842
#
# Epoch 00019: val_acc did not improve from 0.98449
# Epoch 20/100
# 795/795 [==============================] - 192s 242ms/step - loss: 0.0301 - acc: 0.9894 - val_loss: 0.0477 - val_acc: 0.9840
#
# Epoch 00020: val_acc did not improve from 0.98449
# Epoch 21/100
# 795/795 [==============================] - 193s 242ms/step - loss: 0.0298 - acc: 0.9895 - val_loss: 0.0477 - val_acc: 0.9848
#
# Epoch 00021: val_acc improved from 0.98449 to 0.98481, saving model to models/unet_no_drop.h5
# Epoch 22/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0286 - acc: 0.9899 - val_loss: 0.0509 - val_acc: 0.9847
#
# Epoch 00022: val_acc did not improve from 0.98481
# Epoch 23/100
# 795/795 [==============================] - 189s 237ms/step - loss: 0.0285 - acc: 0.9900 - val_loss: 0.0587 - val_acc: 0.9830
#
# Epoch 00023: val_acc did not improve from 0.98481
# Epoch 24/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0282 - acc: 0.9901 - val_loss: 0.0535 - val_acc: 0.9844
#
# Epoch 00024: val_acc did not improve from 0.98481
# Epoch 25/100
# 795/795 [==============================] - 192s 242ms/step - loss: 0.0274 - acc: 0.9904 - val_loss: 0.0516 - val_acc: 0.9846
#
# Epoch 00025: val_acc did not improve from 0.98481
# Epoch 26/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0274 - acc: 0.9904 - val_loss: 0.0499 - val_acc: 0.9846
#
# Epoch 00026: val_acc did not improve from 0.98481
# Epoch 27/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0270 - acc: 0.9905 - val_loss: 0.0509 - val_acc: 0.9842
#
# Epoch 00027: val_acc did not improve from 0.98481
# Epoch 28/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0255 - acc: 0.9911 - val_loss: 0.0513 - val_acc: 0.9845
#
# Epoch 00028: val_acc did not improve from 0.98481
# Epoch 29/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0253 - acc: 0.9911 - val_loss: 0.0614 - val_acc: 0.9837
#
# Epoch 00029: val_acc did not improve from 0.98481
# Epoch 30/100
# 795/795 [==============================] - 190s 238ms/step - loss: 0.0256 - acc: 0.9910 - val_loss: 0.0564 - val_acc: 0.9846
#
# Epoch 00030: val_acc did not improve from 0.98481
# Epoch 31/100
# 795/795 [==============================] - 189s 237ms/step - loss: 0.0253 - acc: 0.9911 - val_loss: 0.0606 - val_acc: 0.9840
#
# Epoch 00031: val_acc did not improve from 0.98481
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 32/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0218 - acc: 0.9924 - val_loss: 0.0568 - val_acc: 0.9853
#
# Epoch 00032: val_acc improved from 0.98481 to 0.98527, saving model to models/unet_no_drop.h5
# Epoch 33/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0208 - acc: 0.9928 - val_loss: 0.0557 - val_acc: 0.9853
#
# Epoch 00033: val_acc improved from 0.98527 to 0.98528, saving model to models/unet_no_drop.h5
# Epoch 34/100
# 795/795 [==============================] - 190s 238ms/step - loss: 0.0204 - acc: 0.9929 - val_loss: 0.0596 - val_acc: 0.9853
#
# Epoch 00034: val_acc improved from 0.98528 to 0.98530, saving model to models/unet_no_drop.h5
# Epoch 35/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0201 - acc: 0.9930 - val_loss: 0.0641 - val_acc: 0.9850
#
# Epoch 00035: val_acc did not improve from 0.98530
# Epoch 36/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0199 - acc: 0.9931 - val_loss: 0.0609 - val_acc: 0.9851
#
# Epoch 00036: val_acc did not improve from 0.98530
# Epoch 37/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0196 - acc: 0.9931 - val_loss: 0.0608 - val_acc: 0.9852
#
# Epoch 00037: val_acc did not improve from 0.98530
# Epoch 38/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0193 - acc: 0.9932 - val_loss: 0.0617 - val_acc: 0.9851
#
# Epoch 00038: val_acc did not improve from 0.98530
# Epoch 39/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0192 - acc: 0.9933 - val_loss: 0.0645 - val_acc: 0.9850
#
# Epoch 00039: val_acc did not improve from 0.98530
# Epoch 40/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0190 - acc: 0.9934 - val_loss: 0.0637 - val_acc: 0.9850
#
# Epoch 00040: val_acc did not improve from 0.98530
# Epoch 41/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0188 - acc: 0.9934 - val_loss: 0.0684 - val_acc: 0.9850
#
# Epoch 00041: val_acc did not improve from 0.98530
# Epoch 42/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0186 - acc: 0.9935 - val_loss: 0.0674 - val_acc: 0.9850
#
# Epoch 00042: val_acc did not improve from 0.98530
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 43/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0181 - acc: 0.9937 - val_loss: 0.0659 - val_acc: 0.9851
#
# Epoch 00043: val_acc did not improve from 0.98530
# Epoch 44/100
# 795/795 [==============================] - 190s 240ms/step - loss: 0.0180 - acc: 0.9937 - val_loss: 0.0686 - val_acc: 0.9850
#
# Epoch 00044: val_acc did not improve from 0.98530
# Epoch 45/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0180 - acc: 0.9937 - val_loss: 0.0680 - val_acc: 0.9850
#
# Epoch 00045: val_acc did not improve from 0.98530
# Epoch 46/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0178 - acc: 0.9938 - val_loss: 0.0686 - val_acc: 0.9850
#
# Epoch 00046: val_acc did not improve from 0.98530
# Epoch 47/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0178 - acc: 0.9938 - val_loss: 0.0700 - val_acc: 0.9849
#
# Epoch 00047: val_acc did not improve from 0.98530
# Epoch 48/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0177 - acc: 0.9938 - val_loss: 0.0702 - val_acc: 0.9849
#
# Epoch 00048: val_acc did not improve from 0.98530
# Epoch 49/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0177 - acc: 0.9938 - val_loss: 0.0717 - val_acc: 0.9849
#
# Epoch 00049: val_acc did not improve from 0.98530
# Epoch 50/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0176 - acc: 0.9938 - val_loss: 0.0712 - val_acc: 0.9849
#
# Epoch 00050: val_acc did not improve from 0.98530
# Epoch 51/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0176 - acc: 0.9938 - val_loss: 0.0711 - val_acc: 0.9849
#
# Epoch 00051: val_acc did not improve from 0.98530
# Epoch 52/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0175 - acc: 0.9939 - val_loss: 0.0708 - val_acc: 0.9849
#
# Epoch 00052: val_acc did not improve from 0.98530
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 53/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0175 - acc: 0.9939 - val_loss: 0.0715 - val_acc: 0.9849
#
# Epoch 00053: val_acc did not improve from 0.98530
# Epoch 54/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0174 - acc: 0.9939 - val_loss: 0.0704 - val_acc: 0.9849
#
# Epoch 00054: val_acc did not improve from 0.98530
# Epoch 55/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0174 - acc: 0.9939 - val_loss: 0.0726 - val_acc: 0.9849
#
# Epoch 00055: val_acc did not improve from 0.98530
# Epoch 56/100
# 795/795 [==============================] - 192s 242ms/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0726 - val_acc: 0.9848
#
# Epoch 00056: val_acc did not improve from 0.98530
# Epoch 57/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0716 - val_acc: 0.9849
#
# Epoch 00057: val_acc did not improve from 0.98530
# Epoch 58/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0174 - acc: 0.9939 - val_loss: 0.0717 - val_acc: 0.9849
#
# Epoch 00058: val_acc did not improve from 0.98530
# Epoch 59/100
# 795/795 [==============================] - 188s 237ms/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0718 - val_acc: 0.9848
#
# Epoch 00059: val_acc did not improve from 0.98530
# Epoch 60/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0714 - val_acc: 0.9849
#
# Epoch 00060: val_acc did not improve from 0.98530
# Epoch 61/100
# 795/795 [==============================] - 188s 237ms/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0716 - val_acc: 0.9849
#
# Epoch 00061: val_acc did not improve from 0.98530
# Epoch 62/100
# 795/795 [==============================] - 188s 236ms/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0720 - val_acc: 0.9849
#
# Epoch 00062: val_acc did not improve from 0.98530
# Epoch 63/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0736 - val_acc: 0.9848
#
# Epoch 00063: val_acc did not improve from 0.98530
# Epoch 64/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0733 - val_acc: 0.9848
#
# Epoch 00064: val_acc did not improve from 0.98530
# Epoch 65/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0172 - acc: 0.9940 - val_loss: 0.0732 - val_acc: 0.9848
#
# Epoch 00065: val_acc did not improve from 0.98530
# Epoch 66/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0726 - val_acc: 0.9848
#
# Epoch 00066: val_acc did not improve from 0.98530
# Epoch 67/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0172 - acc: 0.9940 - val_loss: 0.0728 - val_acc: 0.9848
#
# Epoch 00067: val_acc did not improve from 0.98530
# Epoch 68/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0172 - acc: 0.9940 - val_loss: 0.0728 - val_acc: 0.9848
#
# Epoch 00068: val_acc did not improve from 0.98530
# Epoch 69/100
# 795/795 [==============================] - 193s 243ms/step - loss: 0.0172 - acc: 0.9940 - val_loss: 0.0733 - val_acc: 0.9848
#
# Epoch 00069: val_acc did not improve from 0.98530
# Epoch 70/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0171 - acc: 0.9940 - val_loss: 0.0726 - val_acc: 0.9848
#
# Epoch 00070: val_acc did not improve from 0.98530
# Epoch 71/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0172 - acc: 0.9940 - val_loss: 0.0727 - val_acc: 0.9848
#
# Epoch 00071: val_acc did not improve from 0.98530
# Epoch 72/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0171 - acc: 0.9940 - val_loss: 0.0730 - val_acc: 0.9848
#
# Epoch 00072: val_acc did not improve from 0.98530
# Epoch 73/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0172 - acc: 0.9940 - val_loss: 0.0742 - val_acc: 0.9848
#
# Epoch 00073: val_acc did not improve from 0.98530
# Epoch 74/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0171 - acc: 0.9940 - val_loss: 0.0733 - val_acc: 0.9848
#
# Epoch 00074: val_acc did not improve from 0.98530
# Epoch 75/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0171 - acc: 0.9940 - val_loss: 0.0736 - val_acc: 0.9848
#
# Epoch 00075: val_acc did not improve from 0.98530
# Epoch 76/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0171 - acc: 0.9940 - val_loss: 0.0731 - val_acc: 0.9848
#
# Epoch 00076: val_acc did not improve from 0.98530
# Epoch 77/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0171 - acc: 0.9940 - val_loss: 0.0733 - val_acc: 0.9848
#
# Epoch 00077: val_acc did not improve from 0.98530
# Epoch 78/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0171 - acc: 0.9940 - val_loss: 0.0745 - val_acc: 0.9848
#
# Epoch 00078: val_acc did not improve from 0.98530
# Epoch 79/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0748 - val_acc: 0.9848
#
# Epoch 00079: val_acc did not improve from 0.98530
# Epoch 80/100
# 795/795 [==============================] - 189s 237ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0736 - val_acc: 0.9848
#
# Epoch 00080: val_acc did not improve from 0.98530
# Epoch 81/100
# 795/795 [==============================] - 188s 237ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0737 - val_acc: 0.9848
#
# Epoch 00081: val_acc did not improve from 0.98530
# Epoch 82/100
# 795/795 [==============================] - 188s 237ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0738 - val_acc: 0.9848
# Epoch 00082: val_acc did not improve from 0.98530
# Epoch 83/100
# 795/795 [==============================] - 190s 240ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0745 - val_acc: 0.9848
#
# Epoch 00083: val_acc did not improve from 0.98530
# Epoch 84/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0747 - val_acc: 0.9848
#
# Epoch 00084: val_acc did not improve from 0.98530
# Epoch 85/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0746 - val_acc: 0.9848
#
# Epoch 00085: val_acc did not improve from 0.98530
# Epoch 86/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0744 - val_acc: 0.9848
#
# Epoch 00086: val_acc did not improve from 0.98530
# Epoch 87/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0745 - val_acc: 0.9848
#
# Epoch 00087: val_acc did not improve from 0.98530
# Epoch 88/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0169 - acc: 0.9940 - val_loss: 0.0747 - val_acc: 0.9848
#
# Epoch 00088: val_acc did not improve from 0.98530
# Epoch 89/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0169 - acc: 0.9941 - val_loss: 0.0752 - val_acc: 0.9848
#
# Epoch 00089: val_acc did not improve from 0.98530
# Epoch 90/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0170 - acc: 0.9940 - val_loss: 0.0755 - val_acc: 0.9847
#
# Epoch 00090: val_acc did not improve from 0.98530
# Epoch 91/100
# 795/795 [==============================] - 189s 238ms/step - loss: 0.0169 - acc: 0.9940 - val_loss: 0.0748 - val_acc: 0.9847
#
# Epoch 00091: val_acc did not improve from 0.98530
# Epoch 92/100
# 795/795 [==============================] - 190s 240ms/step - loss: 0.0169 - acc: 0.9941 - val_loss: 0.0749 - val_acc: 0.9847
#
# Epoch 00092: val_acc did not improve from 0.98530
# Epoch 93/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0169 - acc: 0.9940 - val_loss: 0.0747 - val_acc: 0.9847
#
# Epoch 00093: val_acc did not improve from 0.98530
# Epoch 94/100
# 795/795 [==============================] - 192s 241ms/step - loss: 0.0169 - acc: 0.9941 - val_loss: 0.0749 - val_acc: 0.9847
#
# Epoch 00094: val_acc did not improve from 0.98530
# Epoch 95/100
# 795/795 [==============================] - 191s 240ms/step - loss: 0.0169 - acc: 0.9941 - val_loss: 0.0750 - val_acc: 0.9848
#
# Epoch 00095: val_acc did not improve from 0.98530
# Epoch 96/100
# 795/795 [==============================] - 188s 237ms/step - loss: 0.0169 - acc: 0.9941 - val_loss: 0.0748 - val_acc: 0.9847
#
# Epoch 00096: val_acc did not improve from 0.98530
# Epoch 97/100
# 795/795 [==============================] - 190s 239ms/step - loss: 0.0168 - acc: 0.9941 - val_loss: 0.0758 - val_acc: 0.9847
#
# Epoch 00097: val_acc did not improve from 0.98530
# Epoch 98/100
# 795/795 [==============================] - 191s 241ms/step - loss: 0.0168 - acc: 0.9941 - val_loss: 0.0749 - val_acc: 0.9847
#
# Epoch 00098: val_acc did not improve from 0.98530
# Epoch 99/100
# 795/795 [==============================] - 188s 237ms/step - loss: 0.0168 - acc: 0.9941 - val_loss: 0.0756 - val_acc: 0.9847
#
# Epoch 00099: val_acc did not improve from 0.98530
# Epoch 100/100
# 795/795 [==============================] - 189s 237ms/step - loss: 0.0168 - acc: 0.9941 - val_loss: 0.0749 - val_acc: 0.9847
#
# Epoch 00100: val_acc did not improve from 0.98530
